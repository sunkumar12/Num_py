# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales=pd.read_csv(r"C:\Users\user\Desktop\Pyt\python\Sales.csv")

# %%
sales.head()
# Out:
#       Date    Year     Month  Customer Age age bucket gender bucket  \
# 0  2/19/16  2016.0  February          29.0        <31        female
# 1  2/20/16  2016.0  February          29.0        <31        female
# 2  2/27/16  2016.0  February          29.0        <31        female
# 3  3/12/16  2016.0     March          29.0        <31        female
# 4  3/12/16  2016.0     March          29.0        <31        female
#
#   Customer Gender        Country       State Product Category  \
# 0               F  United States  Washington      Accessories
# 1               F  United States  Washington         Clothing
# 2               F  United States  Washington      Accessories
# 3               F  United States  Washington      Accessories
# 4               F  United States  Washington      Accessories
#
#       Sub Category  Quantity  Unit Cost   Unit Price      Cost   Revenue
# 0  Tires and Tubes       1.0      80.00       109.00     80.00    109.00
# ...

# %%
sales.shape
# Out:
# (34867, 16)

# %%
sales.isnull().sum()
# Out:
# Date                1
# Year                1
# Month               1
# Customer Age        1
# age bucket          1
# gender bucket       1
# Customer Gender     1
# Country             1
# State               1
# Product Category    1
# Sub Category        1
# Quantity            1
#  Unit Cost          1
#  Unit Price         1
#  Cost               1
#  Revenue            1
# dtype: int64

# %%
sales.head(2)
# Out:
#       Date    Year     Month  Customer Age age bucket gender bucket  \
# 0  2/19/16  2016.0  February          29.0        <31        female
# 1  2/20/16  2016.0  February          29.0        <31        female
#
#   Customer Gender        Country       State Product Category  \
# 0               F  United States  Washington      Accessories
# 1               F  United States  Washington         Clothing
#
#       Sub Category  Quantity  Unit Cost   Unit Price     Cost   Revenue
# 0  Tires and Tubes       1.0      80.00       109.00    80.00    109.00
# 1           Gloves       2.0      24.50        28.50    49.00     57.00

# %%
sales['Product Category'].value_counts()
# Out:
# Accessories    22534
# Bikes           7093
# Clothing        5239
# Name: Product Category, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# June         3680
# May          3676
# December     3414
# April        3283
# March        3155
# January      2907
# February     2887
# October      2554
# November     2488
# August       2304
# September    2303
# July         2215
# Name: Month, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# United States     18076
# United Kingdom     6421
# Germany            5201
# France             5168
# Name: Country, dtype: int64

# %%
sales.head(2)
# Out:
#       Date    Year     Month  Customer Age age bucket gender bucket  \
# 0  2/19/16  2016.0  February          29.0        <31        female
# 1  2/20/16  2016.0  February          29.0        <31        female
#
#   Customer Gender        Country       State Product Category  \
# 0               F  United States  Washington      Accessories
# 1               F  United States  Washington         Clothing
#
#       Sub Category  Quantity  Unit Cost   Unit Price     Cost   Revenue
# 0  Tires and Tubes       1.0      80.00       109.00    80.00    109.00
# 1           Gloves       2.0      24.50        28.50    49.00     57.00

# %%
sales[sales['Country'].isin(['France','Germany'])]
# Out:
#           Date    Year     Month  Customer Age age bucket gender bucket  \
# 294    2/20/16  2016.0  February          40.0      FALSE        female
# 295    2/20/16  2016.0  February          40.0      FALSE        female
# 296    2/20/16  2016.0  February          40.0      FALSE        female
# 297    2/20/16  2016.0  February          40.0      FALSE        female
# 298    2/20/16  2016.0  February          40.0      FALSE        female
# ...        ...     ...       ...           ...        ...           ...
# 34861  3/22/15  2015.0     March          38.0      FALSE          male
# 34862   2/7/16  2016.0  February          38.0      FALSE          male
# 34863  3/13/15  2015.0     March          38.0      FALSE          male
# 34864   4/5/15  2015.0     April          38.0      FALSE          male
# 34865  8/30/15  2015.0    August          38.0      FALSE          male
#
#       Customer Gender Country              State Product Category  \
# ...

# %%
sales[sales['Quantity'] > 2]
# Out:
#           Date    Year     Month  Customer Age age bucket gender bucket  \
# 2      2/27/16  2016.0  February          29.0        <31        female
# 4      3/12/16  2016.0     March          29.0        <31        female
# 11      7/1/16  2016.0      July          29.0        <31        female
# 14     8/18/15  2015.0    August          29.0        <31        female
# 15     8/30/15  2015.0    August          29.0        <31        female
# ...        ...     ...       ...           ...        ...           ...
# 34847   3/4/16  2016.0     March          37.0      FALSE        female
# 34850  4/27/16  2016.0     April          37.0      FALSE        female
# 34852  2/19/16  2016.0  February          38.0      FALSE          male
# 34856  1/18/16  2016.0   January          37.0      FALSE        female
# 34864   4/5/15  2015.0     April          38.0      FALSE          male
#
#       Customer Gender         Country           State Product Category  \
# ...

# %%
sales[~(sales['Quantity'] > 2)]
# Out:
#           Date    Year     Month  Customer Age age bucket gender bucket  \
# 0      2/19/16  2016.0  February          29.0        <31        female
# 1      2/20/16  2016.0  February          29.0        <31        female
# 3      3/12/16  2016.0     March          29.0        <31        female
# 5       4/8/16  2016.0     April          29.0        <31        female
# 6      4/17/16  2016.0     April          29.0        <31        female
# ...        ...     ...       ...           ...        ...           ...
# 34861  3/22/15  2015.0     March          38.0      FALSE          male
# 34862   2/7/16  2016.0  February          38.0      FALSE          male
# 34863  3/13/15  2015.0     March          38.0      FALSE          male
# 34865  8/30/15  2015.0    August          38.0      FALSE          male
# 34866      NaN     NaN       NaN           NaN        NaN           NaN
#
#       Customer Gender        Country              State Product Category  \
# ...

# %%
sales['Quantity'] = sales['Quantity'].apply(lambda x:x+3)

# %%
sales
# Out:
#           Date    Year     Month  Customer Age age bucket gender bucket  \
# 0      2/19/16  2016.0  February          29.0        <31        female
# 1      2/20/16  2016.0  February          29.0        <31        female
# 2      2/27/16  2016.0  February          29.0        <31        female
# 3      3/12/16  2016.0     March          29.0        <31        female
# 4      3/12/16  2016.0     March          29.0        <31        female
# ...        ...     ...       ...           ...        ...           ...
# 34862   2/7/16  2016.0  February          38.0      FALSE          male
# 34863  3/13/15  2015.0     March          38.0      FALSE          male
# 34864   4/5/15  2015.0     April          38.0      FALSE          male
# 34865  8/30/15  2015.0    August          38.0      FALSE          male
# 34866      NaN     NaN       NaN           NaN        NaN           NaN
#
#       Customer Gender        Country           State Product Category  \
# ...

# %%
import matplotlib.pyplot as plt
plt.show()

# %%
import os

# %%
sales.head()
# Out:
#       Date    Year     Month  Customer Age age bucket gender bucket  \
# 0  2/19/16  2016.0  February          29.0        <31        female
# 1  2/20/16  2016.0  February          29.0        <31        female
# 2  2/27/16  2016.0  February          29.0        <31        female
# 3  3/12/16  2016.0     March          29.0        <31        female
# 4  3/12/16  2016.0     March          29.0        <31        female
#
#   Customer Gender        Country       State Product Category  \
# 0               F  United States  Washington      Accessories
# 1               F  United States  Washington         Clothing
# 2               F  United States  Washington      Accessories
# 3               F  United States  Washington      Accessories
# 4               F  United States  Washington      Accessories
#
#       Sub Category  Quantity  Unit Cost   Unit Price      Cost   Revenue
# 0  Tires and Tubes       1.0      80.00       109.00     80.00    109.00
# ...

# %%
plt.plot(sales['Customer Age'])
plt.show()
print(sales.shape)
# Out:
# (34867, 16)

# %%
plt.plot(sales['Customer Age'])
plt.xticks(range(0,len(sales['Customer Age'])),sales['Date'],rotation =90)
Plt.show()
